# %% [markdown]
# # **Tutorial Brittle-Matrix Composite Structures**
#
# Introduction and tutorial to BMCS apps for the simulation of BMCS.

# %% [markdown]
# Applications are be sorted according to the level of idealization into
#  - material
#  - cross section
#  - material zone
#  - structural member

# %% [markdown]
# | |   |   |   |
# |-|-|-------|------|
# | ![image-15.png](attachment:image-15.png) | ![image-4.png](fig/reinforcement.png)  | ![image-2.png](fig/bond.png) | ![image.png](fig/matrix.png) |
# | ![image-14.png](attachment:image-14.png) | [![image-6.png](fig/pullout.png)](pull_out/pull_out.ipynb) | ![image-7.png](fig/crack_bridge.png)| [![image-8.png](fig/mkappa.png)](mkappa/mkappa.ipynb) |
# | ![image-13.png](attachment:image-13.png)  | [![image-9.png](fig/tension.png)](pull_out/fragmentation.ipynb) | [![image-10.png](fig/bending.png)](bending/bending_3pt.ipynb) | ![image-11.png](fig/compression.png) |

# %% [markdown]
# ## List of currently provided applications

# %% [markdown]
# | No. | Title |
# |- | - |
# | **[8.1. Moment-curvature](tour8_rcbeam/8_1_rc_beam_mkapa.ipynb)** | Moment-curvature relation of a reinforced cross-section |
# | **[8.2. Beam deflection](tour8_rcbeam/8_2_rc_beam_uls_sls.ipynb)** | Semi-analytical nonliner models for beam deflection  |
# | **[8.3. Beam model composition](tour8_rcbeam/8_3_rc_beam_deflection_pstudy.ipynb)** | How to compose a model and a parametric study |
# | **[Multiple cracking](notebooks/bmcs_fragmentation.ipynb)** | Fragmentation of the matrix with random strength |
# | **[Crack-bridge](notebooks/crack_bridge.ipynb)** | Crack bridge response |
# | **[Pull-out](notebooks/bmcs_pullout.ipynb)** | Pull-out of the fiber from the matrix |
